# %%
import tellurium as te
import numpy as np

#model with stress

r = te.loada("""

J1: ->P; r
J2: P->C; f1*F*P
J3: C->P; f2*C
J4: C->S; f3*C

#stress equations

#J6 induces long-term slowly increasing stress
J6: V->F; a + (B*V)

#static
J5: F -o J2; v*F*(1-(F/K))-(F^2/(1+(F^2)))


#uncomment to add capping to model
#J1: ->P; r
#J2: P->C; f1*F*P*U*E
#J3: C->P; f2*C*R
#J4: C->S; f3*C

#J6: U + E -> R; k1*U*E
#J7: R -> U + E; k2*R


P = 0
C = 0
S = 0
F = 2.2
#V = 3

U = 0
R = 64
E = 0
k2 = 0.000385
k1 = 0.0005


#HeLa
r = 0.70
f1 = 1.8
f2 = 1
f3 = .26
K = 100
#a = 0.001
a = 0.002
#B = 0.016
B = 0.028
v = 1


#Events for S and F

# S
//E3: at (C>10): S = S+30

#F
//E3: at (time>70): F = F-5


""")

# %%
#m = r.simulate(0,400,100, ["Time",'P','S','C','F'])
m = r.gillespie(0,150,100,['Time','P','C','S','U','R'])
r.plot()
# Out:
# <div id="8a710dca-5581-41e7-8edb-43fa5054ccc7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8a710dca-5581-41e7-8edb-43fa5054ccc7", [{"type": "scatter", "x": [0.0, 1.5151515151515151, 3.0303030303030303, 4.545454545454545, 6.0606060606060606, 7.575757575757576, 9.09090909090909, 10.606060606060606, 12.121212121212121, 13.636363636363637, 15.151515151515152, 16.666666666666668, 18.18181818181818, 19.696969696969695, 21.21212121212121, 22.727272727272727, 24.242424242424242, 25.757575757575758, 27.272727272727273, 28.78787878787879, 30.303030303030305, 31.818181818181817, 33.333333333333336, 34.84848484848485, 36.36363636363636, 37.878787878787875, 39.39393939393939, 40.90909090909091, 42.42424242424242, 43.93939393939394, 45.45454545454545, 46.96969696969697, 48.484848484848484, 50.0, 51.515151515
# ...
